# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle

# ---------------------------
# State s1
# s1 = [x, y, vx, vy]
# ---------------------------
x, y, vx, vy = 0.8, 0.4, 0.15, 0.15

# Box dimensions
W, H = 1.0, 1.0

# How long to draw the velocity arrow visually
arrow_scale = 1.0

fig, ax = plt.subplots(figsize=(5, 5))

# Draw box
box = Rectangle((0, 0), W, H, fill=False, linewidth=2)
ax.add_patch(box)

# Draw particle
particle = Circle((x, y), 0.025)
ax.add_patch(particle)

# Draw velocity arrow
ax.arrow(
    x, y,
    arrow_scale * vx,
    arrow_scale * vy,
    head_width=0.03,
    head_length=0.04,
    length_includes_head=True
)

# Formatting
ax.set_xlim(-0.05, 1.05)
ax.set_ylim(-0.05, 1.05)
ax.set_aspect('equal')
ax.axis('off')

# Optional title
ax.set_title(r"$s_1 = [0.8,\;0.4,\;0.15,\;0.15]$", fontsize=16)

# Save high-resolution image
plt.savefig("s1_particle.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
import numpy as np

# ---------------------------
# State s1
# ---------------------------
x, y = 0.8, 0.4
vx, vy = 0.15, 0.15

W, H = 1.0, 1.0

fig, ax = plt.subplots(figsize=(5,5))

# Draw box
box = Rectangle((0,0), W, H, fill=False, linewidth=2)
ax.add_patch(box)

# Particle position (blue)
particle = Circle((x, y), 0.025, color="blue")
ax.add_patch(particle)

# Velocity arrow (red)
ax.arrow(
    x, y,
    vx, vy,
    head_width=0.03,
    head_length=0.04,
    length_includes_head=True,
    color="red"
)

# Axis formatting
ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_aspect('equal')

# Ticks
ticks = np.linspace(0,1,6)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

plt.grid(True, alpha=0.2)

# ---------------------------
# Colored title text
# ---------------------------

fig.text(0.35, 0.95, "s₁ = [", fontsize=16)
fig.text(0.45, 0.95, "0.8, 0.4", color="blue", fontsize=16)
fig.text(0.60, 0.95, ", ", fontsize=16)
fig.text(0.62, 0.95, "0.15, 0.15", color="red", fontsize=16)
fig.text(0.75, 0.95, "]", fontsize=16)

plt.savefig("s1_particle_colored.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
import numpy as np

# ---------------------------
# Colors (shared)
# ---------------------------

s1_pos_color = "blue"
s1_vel_color = "red"

s2_pos_color = "green"
s2_vel_color = "purple"

# ---------------------------
# States
# ---------------------------

x1, y1 = 0.8, 0.4
vx, vy = 0.15, 0.15

x2 = x1 + vx
y2 = y1 + vy

# ---------------------------
# Plot
# ---------------------------

fig, ax = plt.subplots(figsize=(6,6))

# Box
ax.add_patch(Rectangle((0,0),1,1, fill=False, linewidth=2))

# ---- s1 ----
ax.add_patch(Circle((x1,y1),0.025,color=s1_pos_color))

ax.arrow(
    x1,y1,
    vx,vy,
    head_width=0.03,
    head_length=0.04,
    color=s1_vel_color,
    length_includes_head=True
)

# ---- s2 ----
ax.add_patch(Circle((x2,y2),0.025,color=s2_pos_color))

ax.arrow(
    x2,y2,
    vx,vy,
    head_width=0.03,
    head_length=0.04,
    color=s2_vel_color,
    length_includes_head=True,
    clip_on=False
)

# ---------------------------
# Axes
# ---------------------------

ax.set_xlim(0,1)
ax.set_ylim(0,1)
ax.set_aspect('equal')

ticks = np.linspace(0,1,6)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

ax.grid(True, alpha=0.2)

# ---------------------------
# Colored title
# ---------------------------

# ---------------------------
# Centered colored title
# ---------------------------

ypos = 1.04

ax.text(0.30, ypos, "s₂ = [", transform=ax.transAxes, fontsize=20, ha="right")

ax.text(0.31, ypos, "0.95, 0.55",
        transform=ax.transAxes,
        fontsize=20,
        color=s2_pos_color,
        ha="left")

ax.text(0.63, ypos, ", ",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

ax.text(0.67, ypos, "0.15, 0.15",
        transform=ax.transAxes,
        fontsize=20,
        color=s2_vel_color,
        ha="left")

ax.text(0.95, ypos, "]",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
import numpy as np

# ---------------------------
# Colors
# ---------------------------
s1_pos_color = "blue"
s1_vel_color = "red"

s2_pos_color = "green"
s2_vel_color = "purple"

s3_pos_color = "orange"
s3_vel_color = "orange"

# ---------------------------
# States
# ---------------------------
# s1
x1, y1 = 0.80, 0.40
vx1, vy1 = 0.15, 0.15

# s2 = free flight from s1
x2, y2 = 0.95, 0.55
vx2, vy2 = 0.15, 0.15

# s3 = reflected at right wall
x3, y3 = 0.95, 0.70
vx3, vy3 = -0.15, 0.15

# ---------------------------
# Figure
# ---------------------------
fig, ax = plt.subplots(figsize=(6, 6))

# Box
ax.add_patch(Rectangle((0, 0), 1, 1, fill=False, linewidth=2, edgecolor="black"))

# s1
ax.add_patch(Circle((x1, y1), 0.025, color=s1_pos_color))
ax.arrow(
    x1, y1, vx1, vy1,
    head_width=0.03, head_length=0.04,
    color=s1_vel_color,
    length_includes_head=True
)

# s2
ax.add_patch(Circle((x2, y2), 0.025, color=s2_pos_color))
ax.arrow(
    x2, y2, vx2, vy2,
    head_width=0.03, head_length=0.04,
    color=s2_vel_color,
    length_includes_head=True,
    clip_on=False
)

# s3
ax.add_patch(Circle((x3, y3), 0.025, color=s3_pos_color))
ax.arrow(
    x3, y3, vx3, vy3,
    head_width=0.03, head_length=0.04,
    color=s3_vel_color,
    length_includes_head=True,
    clip_on=False
)

# Optional: mark wall hit point
ax.plot([1.0], [0.60], marker="x", markersize=10, color="black", mew=2)

# Axes
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_aspect("equal")

ticks = np.linspace(0, 1, 6)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.grid(True, alpha=0.2)

# ---------------------------
# Centered title for s3
# ---------------------------
ypos = 1.04
ax.text(0.39, ypos, "s₃ = [", transform=ax.transAxes, fontsize=20, ha="right")

ax.text(0.40, ypos, "0.95, 0.70",
        transform=ax.transAxes,
        fontsize=20,
        color=s3_pos_color,
        ha="left")

ax.text(0.62, ypos, ", ",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

ax.text(0.66, ypos, "-0.15, 0.15",
        transform=ax.transAxes,
        fontsize=20,
        color=s3_vel_color,
        ha="left")

ax.text(0.91, ypos, "]",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

plt.tight_layout()
plt.savefig("s3_particle_reflection.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
import numpy as np

# ---------------------------
# States
# ---------------------------
# s1
x1, y1 = 0.80, 0.40
vx1, vy1 = 0.15, 0.15

# s2: free flight to wall
x2, y2 = 0.95, 0.55
vx2, vy2 = 0.15, 0.15

# s3: after reflection and one more step
x3, y3 = 0.80, 0.70
vx3, vy3 = -0.15, 0.15

# ---------------------------
# Colors
# ---------------------------
s1_pos = "blue"
s1_vel = "red"

s2_pos = "green"
s2_vel = "purple"

s3_pos = "orange"
s3_vel = "darkorange"

# ---------------------------
# Figure
# ---------------------------
fig, ax = plt.subplots(figsize=(6, 6))

# Box
ax.add_patch(Rectangle((0, 0), 1, 1, fill=False, linewidth=2, edgecolor="black"))

# s1
ax.add_patch(Circle((x1, y1), 0.025, color=s1_pos))
ax.arrow(
    x1, y1, vx1, vy1,
    head_width=0.025, head_length=0.035,
    color=s1_vel,
    length_includes_head=True
)

# s2
ax.add_patch(Circle((x2,y2),0.025,color=s2_pos_color))

ax.arrow(
    x2,y2,
    vx,vy,
    head_width=0.03,
    head_length=0.04,
    color=s2_vel_color,
    length_includes_head=True,
    clip_on=False
)

# s3
ax.add_patch(Circle((x3, y3), 0.025, color=s3_pos))
ax.arrow(
    x3, y3, vx3, vy3,
    head_width=0.025, head_length=0.035,
    color=s3_vel,
    length_includes_head=True
)

# Optional dashed wall cue
ax.plot([1, 1], [0.48, 0.66], linestyle="--", color="gray", alpha=0.6)

# Axes
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_aspect("equal")
ticks = np.linspace(0, 1, 6)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.grid(True, alpha=0.2)



plt.tight_layout(rect=[0, 0, 1, 0.90])
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import numpy as np

# -----------------------
# States (zero radius)
# -----------------------

# s2
x2, y2 = 0.95, 0.55
vx2, vy2 = 0.15, 0.15

# free flight proposal
x_free = x2 + vx2
y_free = y2 + vy2

# s3 after wall reflection
x3, y3 = 1.00, 0.70
vx3, vy3 = -0.15, 0.15

# -----------------------
# Colors
# -----------------------

s2_color = "green"
free_color = "gray"
s3_color = "orange"

incoming_vel = "purple"
reflected_vel = "red"

# -----------------------
# Plot
# -----------------------

fig, ax = plt.subplots(figsize=(6,6))

# Box
ax.add_patch(Rectangle((0,0),1,1,fill=False,linewidth=2,color="black"))


# s1
ax.add_patch(Circle((x1, y1), 0.025, color=s1_pos))
ax.arrow(
    x1, y1, vx1, vy1,
    head_width=0.025, head_length=0.035,
    color=s1_vel,
    length_includes_head=True
)


# s2 point
ax.scatter(x2,y2,color=s2_color,s=80,zorder=3)

# incoming velocity
ax.arrow(x2,y2,vx2,vy2,
         head_width=0.025,
         head_length=0.035,
         color=incoming_vel,
         length_includes_head=True)

# free flight point (outside box)
ax.scatter(x_free,y_free,color=free_color,s=60)

# s3 point on wall
ax.scatter(x3,y3,color=s3_color,s=80,zorder=3)

# reflected velocity
ax.arrow(x3,y3,vx3,vy3,
         head_width=0.025,
         head_length=0.035,
         color=reflected_vel,
         length_includes_head=True)

# dashed path showing overshoot
ax.plot([x2,x_free],[y2,y_free],'--',color="gray",alpha=0.6)

# wall line
ax.axvline(1,color="black",linewidth=2)

# axes
ax.set_xlim(0,1.2)
ax.set_ylim(0,1)
ax.set_aspect("equal")

ticks = np.linspace(0,1,6)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

ax.grid(True,alpha=0.2)

ax.set_title("Zero-radius particle wall reflection",fontsize=18)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 43
#      39 ax.add_patch(Rectangle((0,0),1,1,fill=False,linewidth=2,color="black"))
#      42 # s1
# ---> 43 ax.add_patch(Circle((x1, y1), 0.025, color=s1_pos))
#      44 ax.arrow(
#      45     x1, y1, vx1, vy1,
#      46     head_width=0.025, head_length=0.035,
#      47     color=s1_vel,
#      48     length_includes_head=True
#      49 )
#      52 # s2 point
#
# NameError: name 'Circle' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
import numpy as np

# -----------------------
# States (zero radius)
# -----------------------

# s1
x1, y1 = 0.80, 0.40
vx1, vy1 = 0.15, 0.15

# s2
x2, y2 = 0.95, 0.55
vx2, vy2 = 0.15, 0.15

# free flight proposal from s2
x_free = x2 + vx2
y_free = y2 + vy2

# s3 after wall reflection (clamp to wall, flip vx)
x3, y3 = 1.00, 0.70
vx3, vy3 = -0.15, 0.15

# -----------------------
# Colors
# -----------------------
s1_pos = "blue"
s1_vel = "red"

s2_color = "green"
free_color = "gray"
s3_color = "orange"

incoming_vel = "purple"
reflected_vel = "blue"

# -----------------------
# Plot
# -----------------------
fig, ax = plt.subplots(figsize=(6, 6))

# Box
ax.add_patch(Rectangle((0, 0), 1, 1, fill=False, linewidth=2, color="black"))

# s1
ax.add_patch(Circle((x1, y1), 0.02, color=s1_pos, zorder=3))
ax.arrow(
    x1, y1, vx1, vy1,
    head_width=0.02,
    head_length=0.025,
    color=s1_vel,
    length_includes_head=True,
    zorder=2
)

# s2 point
ax.scatter(x2, y2, color=s2_color, s=80, zorder=4)

# incoming velocity at s2
ax.arrow(
    x2, y2, vx2, vy2,
    head_width=0.02,
    head_length=0.025,
    color=incoming_vel,
    length_includes_head=True,
    zorder=2
)

# free flight point (outside box)
ax.scatter(x_free, y_free, color=free_color, s=60, zorder=3)

# dashed path showing overshoot
ax.plot([x2, x_free], [y2, y_free], "--", color=free_color, alpha=0.6, zorder=1)

# s3 point on wall
ax.scatter(x3, y3, color=s3_color, s=80, zorder=4)

# reflected velocity
ax.arrow(
    x3, y3, vx3, vy3,
    head_width=0.02,
    head_length=0.025,
    color=reflected_vel,
    length_includes_head=True,
    zorder=2
)

# wall line
ax.axvline(1, color="black", linewidth=2)

# axes
ax.set_xlim(0, 1.2)
ax.set_ylim(0, 1.0)
ax.set_aspect("equal")

ticks = np.linspace(0, 1, 6)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

ax.grid(True, alpha=0.2)


# ---------------------------
# Centered colored title
# ---------------------------

ypos = 1.04

ax.text(0.30, ypos, "s₂ = [", transform=ax.transAxes, fontsize=20, ha="right")

ax.text(0.31, ypos, "0.95, 0.55",
        transform=ax.transAxes,
        fontsize=20,
        color=s2_pos_color,
        ha="left")

ax.text(0.63, ypos, ", ",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

ax.text(0.67, ypos, "0.15, 0.15",
        transform=ax.transAxes,
        fontsize=20,
        color=s2_vel_color,
        ha="left")

ax.text(0.95, ypos, "]",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 115
#     108 ypos = 1.04
#     110 ax.text(0.30, ypos, "s₂ = [", transform=ax.transAxes, fontsize=20, ha="right")
#     112 ax.text(0.31, ypos, "0.95, 0.55",
#     113         transform=ax.transAxes,
#     114         fontsize=20,
# --> 115         color=s2_pos_color,
#     116         ha="left")
#     118 ax.text(0.63, ypos, ", ",
#     119         transform=ax.transAxes,
#     120         fontsize=20,
#     121         ha="left")
#     123 ax.text(0.67, ypos, "0.15, 0.15",
#     124         transform=ax.transAxes,
#     125         fontsize=20,
#     126         color=s2_vel_color,
#     127         ha="left")
#
# NameError: name 's2_pos_color' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle
import numpy as np

# -----------------------
# States (zero radius)
# -----------------------

# s1
x1, y1 = 0.80, 0.40
vx1, vy1 = 0.15, 0.15

# s2
x2, y2 = 0.95, 0.55
vx2, vy2 = 0.15, 0.15

# free flight proposal from s2
x_free = x2 + vx2
y_free = y2 + vy2

# s3 after wall reflection (clamp to wall, flip vx)
x3, y3 = 1.00, 0.70
vx3, vy3 = -0.15, 0.15

# -----------------------
# Colors
# -----------------------
s1_pos = "blue"
s1_vel = "red"

s2_color = "green"
free_color = "gray"
s3_color = "orange"

incoming_vel = "purple"
reflected_vel = "blue"

# -----------------------
# Plot
# -----------------------
fig, ax = plt.subplots(figsize=(6, 6))

# Box
ax.add_patch(Rectangle((0, 0), 1, 1, fill=False, linewidth=2, color="black"))

# s1
ax.add_patch(Circle((x1, y1), 0.02, color=s1_pos, zorder=3))
ax.arrow(
    x1, y1, vx1, vy1,
    head_width=0.02,
    head_length=0.025,
    color=s1_vel,
    length_includes_head=True,
    zorder=2
)

# s2 point
ax.scatter(x2, y2, color=s2_color, s=80, zorder=4)

# incoming velocity at s2
ax.arrow(
    x2, y2, vx2, vy2,
    head_width=0.02,
    head_length=0.025,
    color=incoming_vel,
    length_includes_head=True,
    zorder=2
)

# free flight point (outside box)
ax.scatter(x_free, y_free, color=free_color, s=60, zorder=3)

# dashed path showing overshoot
ax.plot([x2, x_free], [y2, y_free], "--", color=free_color, alpha=0.6, zorder=1)

# s3 point on wall
ax.scatter(x3, y3, color=s3_color, s=80, zorder=4)

# reflected velocity
ax.arrow(
    x3, y3, vx3, vy3,
    head_width=0.02,
    head_length=0.025,
    color=reflected_vel,
    length_includes_head=True,
    zorder=2
)

# wall line
ax.axvline(1, color="black", linewidth=2)

# axes
ax.set_xlim(0, 1.2)
ax.set_ylim(0, 1.0)
ax.set_aspect("equal")

ticks = np.linspace(0, 1, 6)
ax.set_xticks(ticks)
ax.set_yticks(ticks)

ax.grid(True, alpha=0.2)

# ---------------------------
# Centered colored title
# ---------------------------
ypos = 1.04

ax.text(0.30, ypos, "s₃ = [", transform=ax.transAxes, fontsize=20, ha="right")

ax.text(0.31, ypos, "1.0, 0.7",
        transform=ax.transAxes,
        fontsize=20,
        color="orange",
        ha="left")

ax.text(0.5, ypos, ", ",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

ax.text(0.55, ypos, "-0.15, 0.15",
        transform=ax.transAxes,
        fontsize=20,
        color="blue",
        ha="left")

ax.text(0.85, ypos, "]",
        transform=ax.transAxes,
        fontsize=20,
        ha="left")

plt.tight_layout()
plt.show()
